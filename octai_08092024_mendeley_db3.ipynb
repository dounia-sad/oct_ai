# %% [markdown]
# <a href="https://colab.research.google.com/github/dounia-sad/oct_ai/blob/main/octai_08092024_mendeley_db3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# installation of library non native to Colab
# !pip install wget
# !pip install scikit-plot
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=c8f1be63ad02ab16e150c43eb4d24b0c095eef7527d0e828244387e8ae4f91ad
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.13.1)
# Requirement already satisfied: joblib>=0.10 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->scikit-plot) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)
# Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Installing collected packages: scikit-plot
# Successfully installed scikit-plot-0.3.7
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 74.7 MB/s eta 0:00:00

# %%
import datetime
import os
import shutil
import zipfile
from math import floor
from random import shuffle

import keras
import matplotlib.pyplot as plt
import numpy as np
import scipy
import seaborn as sns
import tensorflow
import wget
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    classification_report,
    cohen_kappa_score,
    confusion_matrix,
)
from tensorflow.data import AUTOTUNE, Sequential
from tensorflow.keras.applications import VGG19
from tensorflow.keras.callbacks import (
    CSVLogger,
    EarlyStopping,
    ModelCheckpoint,
    TensorBoard,
)
from tensorflow.keras.layers import Dense, Flatten, Input, Rescaling
from tensorflow.keras.losses import BinaryCrossentropy, CategoricalCrossentropy
from tensorflow.keras.metrics import (
    AUC,
    Accuracy,
    BinaryAccuracy,
    CategoricalAccuracy,
    F1Score,
    FalseNegatives,
    FalsePositives,
    MeanAbsoluteError,
    Precision,
    PrecisionAtRecall,
    R2Score,
    Recall,
    RecallAtPrecision,
    RootMeanSquaredError,
    SensitivityAtSpecificity,
    SpecificityAtSensitivity,
    TrueNegatives,
    TruePositives,
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model

# %%
# display version of Python, Tensorflow, Keras and GPU status
# !python --version

print(f"Tensorflow Version: {tensorflow.__version__}")
print(f"Keras Version: {keras.__version__}")
print(f"Scipy Version: {scipy.__version__}")
print("GPU Available:", tensorflow.config.list_physical_devices(device_type="GPU"))
# Out:
# Python 3.10.12
# Tensorflow Version: 2.17.0
# Keras Version: 3.4.1
# Scipy Version: 1.13.1
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
CLASSES = ["NORMAL", "CNV", "DRUSEN", "DME"]  # classes for the multicategorical model
CLASSES_NORMAL_CNV = ["NORMAL", "CNV"]  # classes for binary model normal vs cnv
CLASSES_NORMAL_DRUSEN = [
    "NORMAL",
    "DRUSEN",
]  # classes for binary model normal vs drusen
CLASSES_NORMAL_DME = ["NORMAL", "DME"]  # classes for binary model normal vs dme
IMG_SIZE = 200
VALIDATION_SPLIT = 0.20
RANDOM_STATE = 30
NUM_EPOCHS = 50
TRAIN_BATCH_SIZE = 16
VALIDATION_BATCH_SIZE = 16
TEST_BATCH_SIZE = 50

# %%
# we create a timestamp referene that will be used when saving our various files (weights, models,metrics,..)
time_stamp = datetime.datetime.now().strftime("%Y%m%d-%H%M")
octai_model_version = f"{time_stamp}_octai_model"
octai_model_version
# Out:
# '20240907-1104_octai_model'

# %%
# various files path taht will be used to save our data
dl_data_dir = "CellData/OCT/"
raw_dir = "raw_oct_data/"
data_dir = "model_oct_data/"

# %%
# check if data already downloaded
dowload_data = False if os.path.isdir(dl_data_dir) else True

# %%
if dowload_data:

    # URL for the DOI 10.17632/rscbjbr9sj.3 from Mendeley Data
    octai_ulr = "https://prod-dcd-datasets-cache-zipfiles.s3.eu-west-1.amazonaws.com/rscbjbr9sj-3.zip"

    server_zip = wget.download(octai_ulr)

    # we check if the file downloaded is a zip file
    zipfile.is_zipfile(filename=server_zip)

    # we extract the zip file from the server
    with zipfile.ZipFile(file=server_zip) as zip_ref:
        zip_ref.extractall()

    # we extract the name of the zhang lab data zip file insite the zip file
    zhang_lab_data_zip = list(zipfile.ZipFile(file=server_zip).namelist())[0]

    # we check if the zhang lab datafile downloaded is a zip file
    zipfile.is_zipfile(filename=zhang_lab_data_zip)

    # we extract from the zhang lab data only the OTC scans
    zipdata = zipfile.ZipFile(file=zhang_lab_data_zip)
    for file in zipdata.namelist():
        if file.startswith(dl_data_dir):
            zipdata.extract(member=file)

    # create raw dir file
    os.makedirs(name=os.path.join(raw_dir))

    # we copy all the files from test and train in a new folder called raw_oct_data
    for sub_folder in os.listdir(path=dl_data_dir):
        sub_folder_path = os.path.join(dl_data_dir, sub_folder)
        shutil.copytree(src=sub_folder_path, dst=raw_dir, dirs_exist_ok=True)
        print(f"directory {sub_folder_path} copied to {raw_dir}")

# we delete the all zip files to free space
# !rm -d *.zip
# Out:
# directory CellData/OCT/test copied to raw_oct_data/
# directory CellData/OCT/train copied to raw_oct_data/

# %%
# we define the train/test/split ratio
train_ratio = 0.70
validation_ratio = 0.20
test_ratio = 0.10


# create a small functions that restur list the -jpeg files in a folder
def get_file_list_from_dir(datadir):
    all_files = os.listdir(path=os.path.abspath(path=datadir))
    data_files = list(filter(lambda file: file.endswith(".jpeg"), all_files))
    return data_files


# create sub folder for train/val/test
for dir in ["train", "val", "test"]:
    for _class in os.listdir(path=raw_dir):
        os.makedirs(name=os.path.join(data_dir, dir, _class))

for _class in os.listdir(path=raw_dir):
    class_list = get_file_list_from_dir(datadir=os.path.join(raw_dir, _class))

    # we shuffle the images of the class
    shuffle(x=class_list)

    # we compute the split indices to respect our ratios
    first_split_index = floor(len(class_list) * train_ratio)
    second_split_index = floor(len(class_list) * (train_ratio + validation_ratio))

    train_files = class_list[:first_split_index]
    val_files = class_list[first_split_index:second_split_index]
    test_files = class_list[second_split_index:]

    # we copy our data in the respective destination files
    for file in train_files:
        shutil.copy(
            src=os.path.join(raw_dir, _class, file),
            dst=os.path.join(data_dir, "train", _class, file),
        )

    for file in val_files:
        shutil.copy(
            src=os.path.join(raw_dir, _class, file),
            dst=os.path.join(data_dir, "val", _class, file),
        )

    for file in test_files:
        shutil.copy(
            src=os.path.join(raw_dir, _class, file),
            dst=os.path.join(data_dir, "test", _class, file),
        )

# %%
# we parse our folder structure to count the images per class and for each sub folder train/val/test
file_structure = dict()
classes_count = dict()
classes = []
for sub_cat in os.listdir(path=data_dir):
    file_structure[sub_cat] = {"total": 0}
    for _class in os.listdir(path=os.path.join(data_dir, sub_cat)):
        nb_images = len(os.listdir(path=os.path.join(data_dir, sub_cat, _class)))
        file_structure[sub_cat].update({_class: nb_images})
        file_structure[sub_cat]["total"] += nb_images
        classes.append(_class) if _class not in classes else None

nb_img_train = file_structure["train"]["total"]
nb_img_val = file_structure["val"]["total"]
nb_img_test = file_structure["test"]["total"]
nb_img_total = sum([file_structure[x]["total"] for x in file_structure])

file_structure
# Out:
# {'val': {'total': 21861,
#   'DRUSEN': 1773,
#   'NORMAL': 10277,
#   'DME': 2320,
#   'CNV': 7491},
#  'test': {'total': 10933,
#   'DRUSEN': 887,
#   'NORMAL': 5140,
#   'DME': 1160,
#   'CNV': 3746},
#  'train': {'total': 76515,
#   'DRUSEN': 6206,
#   'NORMAL': 35973,
#   'DME': 8118,
#   'CNV': 26218}}

# %%
# we store the path of the train, validation and test direcorties
train_dir = os.path.join(data_dir + "train/")
val_dir = os.path.join(data_dir + "val/")
test_dir = os.path.join(data_dir + "test/")

# %%
# we print the number of images per train/val/test folder
print(f"Number of images in train: {nb_img_train}")
print(f"Number of images in val: {nb_img_val}")
print(f"Number of images in test: {nb_img_test}")
print(f"Number total of images: {nb_img_total}")
# Out:
# Number of images in train: 76515
# Number of images in val: 21861
# Number of images in test: 10933
# Number total of images: 109309

# %%
# we count total number of images per class
classes_count = {_class: 0 for _class in classes}
for _, v in file_structure.items():
    for _class in classes:
        classes_count[_class] += v[_class]

# we compute the weights of each class and store them for later use in the multiclass model
_class_weight = {k: (v / nb_img_total) for k, v in classes_count.items()}
total_weight = 0
for _class, weight in _class_weight.items():
    print(f"Weight of class {_class}: {weight:0.2%}")
    total_weight += weight

print(f"Total weight: {total_weight:0.2%}")
print(classes_count)
# Out:
# Weight of class DRUSEN: 8.11%
# Weight of class NORMAL: 47.01%
# Weight of class DME: 10.61%
# Weight of class CNV: 34.27%
# Total weight: 100.00%
# {'DRUSEN': 8866, 'NORMAL': 51390, 'DME': 11598, 'CNV': 37455}

# %%
# we compute the weight for each binary class and store them for later use in the binary models
binary_total = sum(v for k, v in classes_count.items() if k in CLASSES_NORMAL_CNV)
weigth_binary_normal_cnv = {
    k: v / binary_total for k, v in classes_count.items() if k in CLASSES_NORMAL_CNV
}

binary_total = sum(v for k, v in classes_count.items() if k in CLASSES_NORMAL_DRUSEN)
weigth_binary_normal_drusen = {
    k: v / binary_total for k, v in classes_count.items() if k in CLASSES_NORMAL_DRUSEN
}

binary_total = sum(v for k, v in classes_count.items() if k in CLASSES_NORMAL_DME)
weigth_binary_normal_dme = {
    k: v / binary_total for k, v in classes_count.items() if k in CLASSES_NORMAL_DME
}

# %%
# we display the total weights per class
palette_color = sns.color_palette(palette="Set2", n_colors=4)
_title = "Weights of classes for the full dataset"
plt.title(label=_title)
plt.pie(
    x=classes_count.values(),
    labels=classes_count.keys(),
    autopct="%1.1f%%",
    colors=palette_color,
)
plt.show()

# %%
# we display the total number of images per class
_title = "Number of images per class for the full dataset"
ax = sns.barplot(
    x=list(classes_count.values()),
    y=list(classes_count.keys()),
    palette=palette_color,
    hue=list(classes_count.keys()),
)
sns.set_style(style="whitegrid")
ax.set_title(label=_title)
for container in ax.containers:
    ax.bar_label(container=container)
sns.despine()

# %%
# we display the number of image per train/val/test set
_title = "Number of images per train/val/test set"
sns.set_style(style="whitegrid")
palette_color_2 = sns.color_palette(palette="Set1", n_colors=3)
ax = sns.barplot(
    x=["train", "val", "test"],
    y=[
        nb_img_train,
        nb_img_val,
        nb_img_test,
    ],
    palette=palette_color_2,
    hue=["train", "val", "test"],
)
ax.set_title(label=_title)
for container in ax.containers:
    ax.bar_label(container=container)
ax.plot()
sns.despine()

# %%
# we compute the class distribution for each train/val/test folder
train_distribution = {
    k: v for k, v in file_structure["train"].items() if k in classes_count.keys()
}
val_distribution = {
    k: v for k, v in file_structure["val"].items() if k in classes_count.keys()
}
test_distribution = {
    k: v for k, v in file_structure["test"].items() if k in classes_count.keys()
}

# %%
_title = "Weights of classes for the folder train"
plt.title(label=_title)
plt.pie(
    x=train_distribution.values(),
    labels=train_distribution.keys(),
    autopct="%1.1f%%",
    colors=palette_color,
)
plt.show()

# %%
_title = "Number of images per class for the folder train"
sns.set_style(style="whitegrid")
ax = sns.barplot(
    x=list(train_distribution.values()),
    y=list(train_distribution.keys()),
    palette=palette_color,
    hue=list(train_distribution.keys()),
)
ax.set_title(label=_title)
for container in ax.containers:
    ax.bar_label(container=container)
ax.plot()
sns.despine()

# %%
_title = "Weights of classes for the folder val"
plt.title(label=_title)
plt.pie(
    x=val_distribution.values(),
    labels=val_distribution.keys(),
    autopct="%1.1f%%",
    colors=palette_color,
)
plt.show()

# %%
_title = "Number of images per class for the folder val"
sns.set_style(style="whitegrid")
ax = sns.barplot(
    x=list(val_distribution.values()),
    y=list(val_distribution.keys()),
    palette=palette_color,
    hue=list(val_distribution.keys()),
)
ax.set_title(label=_title)
for container in ax.containers:
    ax.bar_label(container=container)
ax.plot()
sns.despine()

# %%
_title = "Weights of classes for the folder test"
plt.title(label=_title)
plt.pie(
    x=test_distribution.values(),
    labels=test_distribution.keys(),
    autopct="%1.1f%%",
    colors=palette_color,
)
plt.show()

# %%
_title = "Number of images per class for the folder test"
sns.set_style(style="whitegrid")
ax = sns.barplot(
    x=list(test_distribution.values()),
    y=list(test_distribution.keys()),
    palette=palette_color,
    hue=list(test_distribution.keys()),
)
ax.set_title(label=_title)
for container in ax.containers:
    ax.bar_label(container=container)
ax.plot()
sns.despine()

# %%
# we instentiate our VGG19 model with imagenet weights
model_vgg19 = VGG19(
    weights="imagenet",
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
# we freeze the layers of our model and make is non trainable (no update in weights)
model_vgg19.trainable = False

# %%
# we create our custom octai_model using transfer learning technique
model_octai = Sequential(
    [
        Input((IMG_SIZE, IMG_SIZE, 3)),
        Rescaling(1.0 / 255.0),
        model_vgg19,
        Flatten(),
        Dense(len(CLASSES), activation="softmax"),
    ]
)

# %%
# we create our tensor board to further analyze the model via Tensorboard
tensoboard_log_dir = f"../{octai_model_version}"
tensorboard_callback = TensorBoard()

# we save the log training of our model
csv_logger_callback = CSVLogger(
    f"../{octai_model_version}_training_logger.log", separator=",", append=False
)
model_checkpoint = ModelCheckpoint(filepath="model.{epoch:02d}-{val_loss:.2f}.keras")

# %%
"""we define a list of metrics we would like to keep track off during the traning
and be analysed further to asses the model strenght"""

model_metrics = [
    CategoricalAccuracy(),
    AUC(),
    F1Score(),
    Precision(),
    Recall(),
    Accuracy(),
    RootMeanSquaredError(),
    R2Score(),
    MeanAbsoluteError(),
    TruePositives(),
    TrueNegatives(),
    FalsePositives(),
    FalseNegatives(),
    PrecisionAtRecall(0.5),
    RecallAtPrecision(0.5),
    SensitivityAtSpecificity(0.5),
    SpecificityAtSensitivity(0.5),
]

# %%
# we definie our EarlyStopping function to trigger during the training
early_stopping = EarlyStopping(
    monitor="val_loss", verbose=1, patience=5, restore_best_weights=True
)

# %%
# we compile and build our custom model
model_octai.compile(
    loss=CategoricalCrossentropy(), optimizer=Adam(), metrics=model_metrics
)
model_octai.build()

# we display the summary of our custom training
model_octai.summary(show_trainable=True)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ rescaling (Rescaling)               │ (None, 200, 200, 3)          │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ vgg19 (Functional)                  │ (None, 6, 6, 512)            │    20,024,384 │    N    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ flatten (Flatten)                   │ (None, 18432)                │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ dense (Dense)                       │ (None, 4)                    │        73,732 │    Y    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 20,098,116 (76.67 MB)
#  Trainable params: 73,732 (288.02 KB)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
# we load our training data via a generator to feed our our model
train_ds = keras.utils.image_dataset_from_directory(
    label_mode="categorical",
    directory=train_dir,
    batch_size=TRAIN_BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
)
# Out:
# Found 76515 files belonging to 4 classes.

# %%
# we load our validation data via a generator to feed our our model
val_ds = keras.utils.image_dataset_from_directory(
    label_mode="categorical",
    directory=val_dir,
    batch_size=VALIDATION_BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
)
# Out:
# Found 21861 files belonging to 4 classes.

# %%
# we use keras functionality to optmise the memory and GPU during the feed of the data
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %%
# we definie the weights of each class in a variable to be given to the model
_class_number = {0: "NORMAL", 1: "CNV", 2: "DRUSEN", 3: "DME"}
_class_weight_model = {k: _class_weight[v] for k, v in _class_number.items()}
_class_weight_model
# Out:
# {0: 0.4701351215361956,
#  1: 0.3426524805825687,
#  2: 0.08110951522747441,
#  3: 0.10610288265376136}

# %%
# we start the training of our model
history_vgg = model_octai.fit(
    train_ds,
    epochs=NUM_EPOCHS,
    validation_data=val_ds,
    callbacks=[early_stopping, csv_logger_callback, tensorboard_callback],
    class_weight=_class_weight_model,
    validation_batch_size=VALIDATION_BATCH_SIZE,
)
# Out:
# Epoch 1/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 564s 118ms/step - accuracy: 1.1946e-04 - auc: 0.9382 - categorical_accuracy: 0.8003 - f1_score: 0.6259 - false_negatives: 7324.5933 - false_positives: 6117.2969 - loss: 0.1070 - mean_absolute_error: 0.1210 - precision: 0.8173 - precision_at_recall: 0.9246 - r2_score: 0.4158 - recall: 0.7847 - recall_at_precision: 0.9454 - root_mean_squared_error: 0.2725 - sensitivity_at_specificity: 0.9683 - specificity_at_sensitivity: 0.9849 - true_negatives: 108722.6797 - true_positives: 30955.3984 - val_accuracy: 5.7179e-04 - val_auc: 0.9513 - val_categorical_accuracy: 0.8210 - val_f1_score: 0.6392 - val_false_negatives: 4004.0000 - val_false_positives: 3707.0000 - val_loss: 0.6146 - val_mean_absolute_error: 0.1029 - val_precision: 0.8281 - val_precision_at_recall: 0.9390 - val_r2_score: 0.4342 - val_recall: 0.8168 - val_recall_at_precision: 0.9711 - val_root_mean_squared_error: 0.2638 - val_sensitivity_at_specificity: 0.9711 - val_specificity_at_sensitivity: 0.9889 - val_true_negatives: 61876.0000 - val_true_positives: 17857.0000
# Epoch 2/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 559s 105ms/step - accuracy: 0.0017 - auc: 0.9695 - categorical_accuracy: 0.8727 - f1_score: 0.7541 - false_negatives: 5078.9463 - false_positives: 4602.6611 - loss: 0.0711 - mean_absolute_error: 0.0745 - precision: 0.8786 - precision_at_recall: 0.9722 - r2_score: 0.5926 - recall: 0.8674 - recall_at_precision: 0.9783 - root_mean_squared_error: 0.2240 - sensitivity_at_specificity: 0.9783 - specificity_at_sensitivity: 0.9949 - true_negatives: 110237.3125 - true_positives: 33201.0469 - val_accuracy: 0.0015 - val_auc: 0.9842 - val_categorical_accuracy: 0.9126 - val_f1_score: 0.8280 - val_false_negatives: 1997.0000 - val_false_positives: 1790.0000 - val_loss: 0.2890 - val_mean_absolute_error: 0.0524 - val_precision: 0.9173 - val_precision_at_recall: 0.9876 - val_r2_score: 0.7191 - val_recall: 0.9087 - val_recall_at_precision: 0.9884 - val_root_mean_squared_error: 0.1844 - val_sensitivity_at_specificity: 0.9884 - val_specificity_at_sensitivity: 0.9976 - val_true_negatives: 63793.0000 - val_true_positives: 19864.0000
# Epoch 3/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 502s 105ms/step - accuracy: 0.0041 - auc: 0.9721 - categorical_accuracy: 0.8826 - f1_score: 0.7734 - false_negatives: 4648.2700 - false_positives: 4279.9727 - loss: 0.0661 - mean_absolute_error: 0.0672 - precision: 0.8871 - precision_at_recall: 0.9751 - r2_score: 0.6209 - recall: 0.8783 - recall_at_precision: 0.9769 - root_mean_squared_error: 0.2153 - sensitivity_at_specificity: 0.9769 - specificity_at_sensitivity: 0.9953 - true_negatives: 110560.0000 - true_positives: 33631.7227 - val_accuracy: 0.0013 - val_auc: 0.9840 - val_categorical_accuracy: 0.9049 - val_f1_score: 0.8386 - val_false_negatives: 2185.0000 - val_false_positives: 1932.0000 - val_loss: 0.2951 - val_mean_absolute_error: 0.0602 - val_precision: 0.9106 - val_precision_at_recall: 0.9881 - val_r2_score: 0.6983 - val_recall: 0.9001 - val_recall_at_precision: 0.9914 - val_root_mean_squared_error: 0.1897 - val_sensitivity_at_specificity: 0.9914 - val_specificity_at_sensitivity: 0.9978 - val_true_negatives: 63651.0000 - val_true_positives: 19676.0000
# Epoch 4/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 545s 114ms/step - accuracy: 0.0071 - auc: 0.9748 - categorical_accuracy: 0.8931 - f1_score: 0.7972 - false_negatives: 4190.3574 - false_positives: 3860.4487 - loss: 0.0616 - mean_absolute_error: 0.0616 - precision: 0.8977 - precision_at_recall: 0.9771 - r2_score: 0.6523 - recall: 0.8896 - recall_at_precision: 0.9775 - root_mean_squared_error: 0.2064 - sensitivity_at_specificity: 0.9775 - specificity_at_sensitivity: 0.9954 - true_negatives: 110979.5234 - true_positives: 34089.6328 - val_accuracy: 0.0489 - val_auc: 0.9286 - val_categorical_accuracy: 0.8453 - val_f1_score: 0.6330 - val_false_negatives: 3420.0000 - val_false_positives: 3335.0000 - val_loss: 1.1254 - val_mean_absolute_error: 0.0828 - val_precision: 0.8468 - val_precision_at_recall: 0.9020 - val_r2_score: 0.4602 - val_recall: 0.8436 - val_recall_at_precision: 0.9113 - val_root_mean_squared_error: 0.2620 - val_sensitivity_at_specificity: 0.9113 - val_specificity_at_sensitivity: 0.9777 - val_true_negatives: 62248.0000 - val_true_positives: 18441.0000
# Epoch 5/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 517s 104ms/step - accuracy: 0.0094 - auc: 0.9769 - categorical_accuracy: 0.8986 - f1_score: 0.8036 - false_negatives: 3967.8420 - false_positives: 3681.5522 - loss: 0.0581 - mean_absolute_error: 0.0582 - precision: 0.9029 - precision_at_recall: 0.9791 - r2_score: 0.6651 - recall: 0.8961 - recall_at_precision: 0.9790 - root_mean_squared_error: 0.2017 - sensitivity_at_specificity: 0.9790 - specificity_at_sensitivity: 0.9956 - true_negatives: 111158.4219 - true_positives: 34312.1484 - val_accuracy: 0.0049 - val_auc: 0.9836 - val_categorical_accuracy: 0.9108 - val_f1_score: 0.8459 - val_false_negatives: 2053.0000 - val_false_positives: 1830.0000 - val_loss: 0.3008 - val_mean_absolute_error: 0.0559 - val_precision: 0.9154 - val_precision_at_recall: 0.9878 - val_r2_score: 0.7150 - val_recall: 0.9061 - val_recall_at_precision: 0.9892 - val_root_mean_squared_error: 0.1872 - val_sensitivity_at_specificity: 0.9892 - val_specificity_at_sensitivity: 0.9978 - val_true_negatives: 63753.0000 - val_true_positives: 19808.0000
# Epoch 6/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 502s 105ms/step - accuracy: 0.0104 - auc: 0.9789 - categorical_accuracy: 0.9052 - f1_score: 0.8189 - false_negatives: 3762.5042 - false_positives: 3513.7188 - loss: 0.0522 - mean_absolute_error: 0.0544 - precision: 0.9083 - precision_at_recall: 0.9807 - r2_score: 0.6874 - recall: 0.9025 - recall_at_precision: 0.9802 - root_mean_squared_error: 0.1946 - sensitivity_at_specificity: 0.9802 - specificity_at_sensitivity: 0.9958 - true_negatives: 111326.2578 - true_positives: 34517.4883 - val_accuracy: 0.0058 - val_auc: 0.9848 - val_categorical_accuracy: 0.9158 - val_f1_score: 0.8557 - val_false_negatives: 1920.0000 - val_false_positives: 1711.0000 - val_loss: 0.2831 - val_mean_absolute_error: 0.0522 - val_precision: 0.9210 - val_precision_at_recall: 0.9887 - val_r2_score: 0.7326 - val_recall: 0.9122 - val_recall_at_precision: 0.9889 - val_root_mean_squared_error: 0.1812 - val_sensitivity_at_specificity: 0.9889 - val_specificity_at_sensitivity: 0.9978 - val_true_negatives: 63872.0000 - val_true_positives: 19941.0000
# Epoch 7/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 543s 113ms/step - accuracy: 0.0138 - auc: 0.9784 - categorical_accuracy: 0.9073 - f1_score: 0.8228 - false_negatives: 3604.4150 - false_positives: 3387.5815 - loss: 0.0534 - mean_absolute_error: 0.0530 - precision: 0.9105 - precision_at_recall: 0.9783 - r2_score: 0.6908 - recall: 0.9052 - recall_at_precision: 0.9789 - root_mean_squared_error: 0.1937 - sensitivity_at_specificity: 0.9789 - specificity_at_sensitivity: 0.9952 - true_negatives: 111452.3906 - true_positives: 34675.5781 - val_accuracy: 0.0058 - val_auc: 0.9849 - val_categorical_accuracy: 0.9161 - val_f1_score: 0.8595 - val_false_negatives: 1884.0000 - val_false_positives: 1750.0000 - val_loss: 0.2842 - val_mean_absolute_error: 0.0506 - val_precision: 0.9195 - val_precision_at_recall: 0.9882 - val_r2_score: 0.7263 - val_recall: 0.9138 - val_recall_at_precision: 0.9882 - val_root_mean_squared_error: 0.1811 - val_sensitivity_at_specificity: 0.9882 - val_specificity_at_sensitivity: 0.9976 - val_true_negatives: 63833.0000 - val_true_positives: 19977.0000
# Epoch 8/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 503s 105ms/step - accuracy: 0.0156 - auc: 0.9802 - categorical_accuracy: 0.9104 - f1_score: 0.8286 - false_negatives: 3519.3921 - false_positives: 3296.7649 - loss: 0.0501 - mean_absolute_error: 0.0510 - precision: 0.9134 - precision_at_recall: 0.9804 - r2_score: 0.7034 - recall: 0.9079 - recall_at_precision: 0.9806 - root_mean_squared_error: 0.1894 - sensitivity_at_specificity: 0.9806 - specificity_at_sensitivity: 0.9956 - true_negatives: 111543.2109 - true_positives: 34760.5977 - val_accuracy: 0.0061 - val_auc: 0.9626 - val_categorical_accuracy: 0.8374 - val_f1_score: 0.7779 - val_false_negatives: 3702.0000 - val_false_positives: 3295.0000 - val_loss: 0.5179 - val_mean_absolute_error: 0.0940 - val_precision: 0.8464 - val_precision_at_recall: 0.9598 - val_r2_score: 0.5097 - val_recall: 0.8307 - val_recall_at_precision: 0.9809 - val_root_mean_squared_error: 0.2479 - val_sensitivity_at_specificity: 0.9809 - val_specificity_at_sensitivity: 0.9927 - val_true_negatives: 62288.0000 - val_true_positives: 18159.0000
# Epoch 9/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 604s 114ms/step - accuracy: 0.0182 - auc: 0.9802 - categorical_accuracy: 0.9112 - f1_score: 0.8297 - false_negatives: 3383.3379 - false_positives: 3193.7317 - loss: 0.0494 - mean_absolute_error: 0.0501 - precision: 0.9137 - precision_at_recall: 0.9808 - r2_score: 0.7049 - recall: 0.9093 - recall_at_precision: 0.9799 - root_mean_squared_error: 0.1884 - sensitivity_at_specificity: 0.9799 - specificity_at_sensitivity: 0.9955 - true_negatives: 111646.2422 - true_positives: 34896.6523 - val_accuracy: 0.0083 - val_auc: 0.9843 - val_categorical_accuracy: 0.9187 - val_f1_score: 0.8610 - val_false_negatives: 1827.0000 - val_false_positives: 1700.0000 - val_loss: 0.2899 - val_mean_absolute_error: 0.0487 - val_precision: 0.9218 - val_precision_at_recall: 0.9865 - val_r2_score: 0.7355 - val_recall: 0.9164 - val_recall_at_precision: 0.9865 - val_root_mean_squared_error: 0.1795 - val_sensitivity_at_specificity: 0.9865 - val_specificity_at_sensitivity: 0.9971 - val_true_negatives: 63883.0000 - val_true_positives: 20034.0000
# Epoch 10/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 563s 114ms/step - accuracy: 0.0203 - auc: 0.9812 - categorical_accuracy: 0.9174 - f1_score: 0.8451 - false_negatives: 3249.0806 - false_positives: 3037.2339 - loss: 0.0467 - mean_absolute_error: 0.0469 - precision: 0.9207 - precision_at_recall: 0.9804 - r2_score: 0.7258 - recall: 0.9154 - recall_at_precision: 0.9804 - root_mean_squared_error: 0.1824 - sensitivity_at_specificity: 0.9804 - specificity_at_sensitivity: 0.9954 - true_negatives: 111802.7422 - true_positives: 35030.9102 - val_accuracy: 0.0149 - val_auc: 0.9836 - val_categorical_accuracy: 0.9242 - val_f1_score: 0.8535 - val_false_negatives: 1701.0000 - val_false_positives: 1601.0000 - val_loss: 0.3010 - val_mean_absolute_error: 0.0422 - val_precision: 0.9264 - val_precision_at_recall: 0.9819 - val_r2_score: 0.7462 - val_recall: 0.9222 - val_recall_at_precision: 0.9823 - val_root_mean_squared_error: 0.1752 - val_sensitivity_at_specificity: 0.9823 - val_specificity_at_sensitivity: 0.9955 - val_true_negatives: 63982.0000 - val_true_positives: 20160.0000
# Epoch 11/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 546s 114ms/step - accuracy: 0.0209 - auc: 0.9830 - categorical_accuracy: 0.9193 - f1_score: 0.8458 - false_negatives: 3178.0332 - false_positives: 2985.1272 - loss: 0.0434 - mean_absolute_error: 0.0455 - precision: 0.9221 - precision_at_recall: 0.9820 - r2_score: 0.7334 - recall: 0.9174 - recall_at_precision: 0.9827 - root_mean_squared_error: 0.1793 - sensitivity_at_specificity: 0.9827 - specificity_at_sensitivity: 0.9957 - true_negatives: 111854.8438 - true_positives: 35101.9570 - val_accuracy: 0.0401 - val_auc: 0.9709 - val_categorical_accuracy: 0.9018 - val_f1_score: 0.7820 - val_false_negatives: 2174.0000 - val_false_positives: 2094.0000 - val_loss: 0.4961 - val_mean_absolute_error: 0.0506 - val_precision: 0.9039 - val_precision_at_recall: 0.9643 - val_r2_score: 0.6527 - val_recall: 0.9006 - val_recall_at_precision: 0.9631 - val_root_mean_squared_error: 0.2050 - val_sensitivity_at_specificity: 0.9631 - val_specificity_at_sensitivity: 0.9901 - val_true_negatives: 63489.0000 - val_true_positives: 19687.0000
# Epoch 12/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 517s 105ms/step - accuracy: 0.0230 - auc: 0.9835 - categorical_accuracy: 0.9219 - f1_score: 0.8516 - false_negatives: 3060.9216 - false_positives: 2882.7666 - loss: 0.0424 - mean_absolute_error: 0.0442 - precision: 0.9244 - precision_at_recall: 0.9829 - r2_score: 0.7400 - recall: 0.9202 - recall_at_precision: 0.9829 - root_mean_squared_error: 0.1769 - sensitivity_at_specificity: 0.9829 - specificity_at_sensitivity: 0.9959 - true_negatives: 111957.2031 - true_positives: 35219.0703 - val_accuracy: 0.0486 - val_auc: 0.9709 - val_categorical_accuracy: 0.9044 - val_f1_score: 0.7949 - val_false_negatives: 2116.0000 - val_false_positives: 2056.0000 - val_loss: 0.5026 - val_mean_absolute_error: 0.0496 - val_precision: 0.9057 - val_precision_at_recall: 0.9634 - val_r2_score: 0.6620 - val_recall: 0.9032 - val_recall_at_precision: 0.9625 - val_root_mean_squared_error: 0.2033 - val_sensitivity_at_specificity: 0.9625 - val_specificity_at_sensitivity: 0.9898 - val_true_negatives: 63527.0000 - val_true_positives: 19745.0000
# Epoch 13/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 545s 114ms/step - accuracy: 0.0263 - auc: 0.9839 - categorical_accuracy: 0.9229 - f1_score: 0.8560 - false_negatives: 2981.5881 - false_positives: 2811.3005 - loss: 0.0426 - mean_absolute_error: 0.0436 - precision: 0.9252 - precision_at_recall: 0.9835 - r2_score: 0.7452 - recall: 0.9209 - recall_at_precision: 0.9832 - root_mean_squared_error: 0.1756 - sensitivity_at_specificity: 0.9832 - specificity_at_sensitivity: 0.9960 - true_negatives: 112028.6719 - true_positives: 35298.4023 - val_accuracy: 0.0199 - val_auc: 0.9836 - val_categorical_accuracy: 0.9221 - val_f1_score: 0.8591 - val_false_negatives: 1739.0000 - val_false_positives: 1644.0000 - val_loss: 0.3075 - val_mean_absolute_error: 0.0443 - val_precision: 0.9245 - val_precision_at_recall: 0.9823 - val_r2_score: 0.7403 - val_recall: 0.9205 - val_recall_at_precision: 0.9834 - val_root_mean_squared_error: 0.1778 - val_sensitivity_at_specificity: 0.9834 - val_specificity_at_sensitivity: 0.9958 - val_true_negatives: 63939.0000 - val_true_positives: 20122.0000
# Epoch 14/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 546s 114ms/step - accuracy: 0.0282 - auc: 0.9841 - categorical_accuracy: 0.9247 - f1_score: 0.8576 - false_negatives: 2918.3052 - false_positives: 2771.5093 - loss: 0.0413 - mean_absolute_error: 0.0425 - precision: 0.9269 - precision_at_recall: 0.9832 - r2_score: 0.7497 - recall: 0.9234 - recall_at_precision: 0.9831 - root_mean_squared_error: 0.1737 - sensitivity_at_specificity: 0.9831 - specificity_at_sensitivity: 0.9959 - true_negatives: 112068.4609 - true_positives: 35361.6875 - val_accuracy: 0.0492 - val_auc: 0.9735 - val_categorical_accuracy: 0.9100 - val_f1_score: 0.8070 - val_false_negatives: 1991.0000 - val_false_positives: 1926.0000 - val_loss: 0.4644 - val_mean_absolute_error: 0.0465 - val_precision: 0.9116 - val_precision_at_recall: 0.9667 - val_r2_score: 0.6831 - val_recall: 0.9089 - val_recall_at_precision: 0.9660 - val_root_mean_squared_error: 0.1960 - val_sensitivity_at_specificity: 0.9660 - val_specificity_at_sensitivity: 0.9907 - val_true_negatives: 63657.0000 - val_true_positives: 19870.0000
# Epoch 15/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 562s 114ms/step - accuracy: 0.0300 - auc: 0.9844 - categorical_accuracy: 0.9267 - f1_score: 0.8607 - false_negatives: 2837.6956 - false_positives: 2695.3567 - loss: 0.0387 - mean_absolute_error: 0.0412 - precision: 0.9288 - precision_at_recall: 0.9832 - r2_score: 0.7558 - recall: 0.9256 - recall_at_precision: 0.9830 - root_mean_squared_error: 0.1713 - sensitivity_at_specificity: 0.9830 - specificity_at_sensitivity: 0.9959 - true_negatives: 112144.6172 - true_positives: 35442.2969 - val_accuracy: 0.0283 - val_auc: 0.9711 - val_categorical_accuracy: 0.8917 - val_f1_score: 0.7816 - val_false_negatives: 2399.0000 - val_false_positives: 2318.0000 - val_loss: 0.4844 - val_mean_absolute_error: 0.0581 - val_precision: 0.8936 - val_precision_at_recall: 0.9689 - val_r2_score: 0.6286 - val_recall: 0.8903 - val_recall_at_precision: 0.9680 - val_root_mean_squared_error: 0.2113 - val_sensitivity_at_specificity: 0.9680 - val_specificity_at_sensitivity: 0.9926 - val_true_negatives: 63265.0000 - val_true_positives: 19462.0000
# Epoch 16/50
# 4783/4783 ━━━━━━━━━━━━━━━━━━━━ 502s 105ms/step - accuracy: 0.0318 - auc: 0.9848 - categorical_accuracy: 0.9287 - f1_score: 0.8653 - false_negatives: 2801.7388 - false_positives: 2660.0896 - loss: 0.0386 - mean_absolute_error: 0.0406 - precision: 0.9307 - precision_at_recall: 0.9845 - r2_score: 0.7597 - recall: 0.9272 - recall_at_precision: 0.9834 - root_mean_squared_error: 0.1699 - sensitivity_at_specificity: 0.9834 - specificity_at_sensitivity: 0.9961 - true_negatives: 112179.8828 - true_positives: 35478.2539 - val_accuracy: 0.0193 - val_auc: 0.9837 - val_categorical_accuracy: 0.9262 - val_f1_score: 0.8715 - val_false_negatives: 1652.0000 - val_false_positives: 1564.0000 - val_loss: 0.3014 - val_mean_absolute_error: 0.0416 - val_precision: 0.9282 - val_precision_at_recall: 0.9816 - val_r2_score: 0.7518 - val_recall: 0.9244 - val_recall_at_precision: 0.9821 - val_root_mean_squared_error: 0.1729 - val_sensitivity_at_specificity: 0.9821 - val_specificity_at_sensitivity: 0.9954 - val_true_negatives: 64019.0000 - val_true_positives: 20209.0000
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 6.

# %%
# we save our trained model
model_octai.save(f"{octai_model_version}.keras")

# serialize model to JSON
model_json = model_octai.to_json()
with open(file=f"{octai_model_version}.json", mode="w") as json_file:
    json_file.write(model_json)

# we save model weights in a HDF5 file
model_octai.save_weights(f"{octai_model_version}.weights.h5")

# %%
# we define the metrics we chose to display
display_metrics = [
    "accuracy",
    "auc",
    "categorical_accuracy",
    "loss",
    "mean_absolute_error",
    "precision",
    "precision_at_recall",
    "r2_score",
    "recall",
    "recall_at_precision",
    "root_mean_squared_error",
    "sensitivity_at_specificity",
    "specificity_at_sensitivity",
]
display_metrics = [m for m in history_vgg.history.keys() if "val_" not in m]
display_metrics = [m for m in display_metrics if "f1_" not in m]

# %%
# we diplay a graph for all the metrics we chose to display
plt.rcParams["axes.grid"] = True
for train_metric_name, train_metric_value in history_vgg.history.items():
    if train_metric_name in display_metrics:
        val_metric_name = "val_" + train_metric_name

        train_metric_data = dict(
            zip(
                range(len(history_vgg.history[train_metric_name])),
                history_vgg.history[train_metric_name],
            )
        )
        val_metric_data = dict(
            zip(
                range(len(history_vgg.history[val_metric_name])),
                history_vgg.history[val_metric_name],
            )
        )
        sns.lineplot(
            data=train_metric_data,
            x=train_metric_data.keys(),
            y=train_metric_data.values(),
            label="Train Data",
        )
        sns.lineplot(
            data=val_metric_data,
            x=val_metric_data.keys(),
            y=val_metric_data.values(),
            label="Validation Data",
        )
        ax = plt.gca()
        ax.set_ylim(bottom=[0, 1])
        plt.xlabel(xlabel="Epochs")
        metric = train_metric_name.replace("_", " ")
        plt.ylabel(ylabel=metric)
        plt.title(label=f"Training and validation {metric}")
        plt.legend()
        plt.show()
        print("")

# %%
# we load our test data via a generator to test the accuary of our model
test_ds = keras.utils.image_dataset_from_directory(
    label_mode="categorical",
    directory=test_dir,
    batch_size=TEST_BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
    shuffle=False,
)

# %%
# we evaluate our trained model using our test data
baseline_results = model_octai.evaluate(test_ds)

# %%
# we print the metrics of our trained model based on our test data
for name, value in zip(
    ["loss"] + [metric.name for metric in model_metrics], baseline_results
):
    print(name, ": ", value)
# Out:
# loss :  0.28742796182632446
# categorical_accuracy :  0.9140217900276184
# auc :  0.9845112562179565
# f1_score :  tf.Tensor([0.94226027 0.838929   0.66112757 0.9520798 ], shape=(4,), dtype=float32)
# precision :  0.918427586555481
# recall :  0.9103631377220154
# accuracy :  0.0066770329140126705
# root_mean_squared_error :  0.1823711097240448
# r2_score :  0.7267706394195557
# mean_absolute_error :  0.05223292484879494
# true_positives :  9953.0
# true_negatives :  31915.0
# false_positives :  884.0
# false_negatives :  980.0
# precision_at_recall :  0.9889607429504395
# recall_at_precision :  0.9882923364639282
# sensitivity_at_specificity :  0.9882923364639282
# specificity_at_sensitivity :  0.9978657960891724

# %%
# we compute predictions to compute additional metrics
predictions = model_octai.predict(test_ds)
# Out:
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 52s 236ms/step

# %%
predicted_classes = np.argmax(a=predictions, axis=1)

true_classes = tensorflow.concat(values=[y for _, y in test_ds], axis=0)
true_classes = np.argmax(true_classes, axis=1)
# Out:
# array([0, 0, 0, ..., 3, 3, 3])

# %%
# we compute the confusition matrix
cm_normalized = confusion_matrix(
    y_true=predicted_classes, y_pred=true_classes, normalize="true"
)
cm = confusion_matrix(y_true=predicted_classes, y_pred=true_classes)

# %%
test_classification_report = classification_report(
    y_true=true_classes, y_pred=predicted_classes
)
print(test_classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94      3746
#            1       0.83      0.85      0.84      1160
#            2       0.70      0.63      0.66       887
#            3       0.97      0.94      0.95      5140
#
#     accuracy                           0.91     10933
#    macro avg       0.85      0.85      0.85     10933
# weighted avg       0.91      0.91      0.91     10933

# %%
# we print the confusion matrix
plt.rcParams["axes.grid"] = False
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_ds.class_names)
disp = disp.plot(cmap=plt.cm.Blues)
plt.show()

# %%
# we print the confusion matrix normalised
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm_normalized, display_labels=test_ds.class_names
)
disp = disp.plot(cmap=plt.cm.Blues)
plt.show()

# %%
"""RocCurveDisplay, roc_auc_score, log_loss"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-2f67d51d5262> in <cell line: 1>()
# ----> 1 accu = accuracy_score(true_classes, predicted_classes)
#
# NameError: name 'accuracy_score' is not defined

# %%
# we compute the cohen_kapp score
cohen_kappa = cohen_kappa_score(y1=true_classes, y2=predicted_classes)
cohen_kappa
# Out:
# 0.8665296718559731

# %%
"""roc_auc_ovo = roc_auc_score(y_true=true_classes, y_score=predicted_classes, multi_class="ovo")"""
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-98-6f4575714ba2> in <cell line: 1>()
# ----> 1 roc_auc_ovo = roc_auc_score(true_classes, predicted_classes,multi_class="ovo")
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     212                     )
#     213                 ):
# --> 214                     return func(*args, **kwargs)
#     215             except InvalidParameterError as e:
#     216                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     619         if multi_class == "raise":
#     620             raise ValueError("multi_class must be in ('ovo', 'ovr')")
# --> 621         return _multiclass_roc_auc_score(
#     622             y_true, y_score, labels, multi_class, average, sample_weight
#     623         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py in _multiclass_roc_auc_score(y_true, y_score, labels, multi_class, average, sample_weight)
#     691     """
#     692     # validation of the input y_score
# --> 693     if not np.allclose(1, y_score.sum(axis=1)):
#     694         raise ValueError(
#     695             "Target scores need to be probabilities for multiclass "
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      50
#      51 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
"""roc_auc_ovr = roc_auc_score(y_true=true_classes, y_score=predicted_classes, multi_class="ovr")"""
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-100-9dc9bbef036e> in <cell line: 1>()
# ----> 1 roc_auc_ovr = roc_auc_score(true_classes, predicted_classes,multi_class="ovr")
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     212                     )
#     213                 ):
# --> 214                     return func(*args, **kwargs)
#     215             except InvalidParameterError as e:
#     216                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     619         if multi_class == "raise":
#     620             raise ValueError("multi_class must be in ('ovo', 'ovr')")
# --> 621         return _multiclass_roc_auc_score(
#     622             y_true, y_score, labels, multi_class, average, sample_weight
#     623         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py in _multiclass_roc_auc_score(y_true, y_score, labels, multi_class, average, sample_weight)
#     691     """
#     692     # validation of the input y_score
# --> 693     if not np.allclose(1, y_score.sum(axis=1)):
#     694         raise ValueError(
#     695             "Target scores need to be probabilities for multiclass "
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      50
#      51 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
# we display the shape of the model
plot_model(
    model_octai,
    show_shapes=True,
    show_layer_names=True,
    expand_nested=True,
    show_trainable=True,
)

# %%
# roc_disp = RocCurveDisplay.from_predictions(predicted_classes, true_classes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-bb408bf77b80> in <cell line: 1>()
# ----> 1 roc_disp = RocCurveDisplay.from_predictions(predicted_classes, true_classes)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_plot/roc_curve.py in from_predictions(cls, y_true, y_pred, sample_weight, drop_intermediate, pos_label, name, ax, plot_chance_level, chance_level_kw, **kwargs)
#     384         >>> plt.show()
#     385         """
# --> 386         pos_label_validated, name = cls._validate_from_predictions_params(
#     387             y_true, y_pred, sample_weight=sample_weight, pos_label=pos_label, name=name
#     388         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_plotting.py in _validate_from_predictions_params(cls, y_true, y_pred, sample_weight, pos_label, name)
#      48
#      49         if type_of_target(y_true) != "binary":
# ---> 50             raise ValueError(
#      51                 f"The target y is not binary. Got {type_of_target(y_true)} type of"
#      52                 " target."
#
# ValueError: The target y is not binary. Got multiclass type of target.

# %%
"""fig, ax = plt.subplots(figsize=(10, 10))
target_names = iris_data.target_names
colors = cycle(test_ds.class_names)
for class_id, color in zip(range(n_classes), colors):
    RocCurveDisplay.from_predictions(
        test_y[:, class_id],
        prob_test_vec[:, class_id],
        name=f"ROC curve for {target_names[class_id]}",
        color=color,
        ax=ax,
    )"""

# %%
# we create our custom octai_model_binary models

model_octai_binary_normal_cnv = Sequential(
    [
        Input((IMG_SIZE, IMG_SIZE, 3)),
        Rescaling(1.0 / 255.0),
        model_vgg19,
        Flatten(),
        Dense(1, activation="sigmoid"),
    ]
)

model_octai_binary_normal_drusen = Sequential(
    [
        Input((IMG_SIZE, IMG_SIZE, 3)),
        Rescaling(1.0 / 255.0),
        model_vgg19,
        Flatten(),
        Dense(1, activation="sigmoid"),
    ]
)


model_octai_binary_normal_dme = Sequential(
    [
        Input((IMG_SIZE, IMG_SIZE, 3)),
        Rescaling(1.0 / 255.0),
        model_vgg19,
        Flatten(),
        Dense(1, activation="sigmoid"),
    ]
)

# %%
# we save the log training of our binary model

csv_logger_callback_binary_normal_cnv = CSVLogger(
    f"../{octai_model_version}_training_logger_binary_normal_cnv.log",
    separator=",",
    append=False,
)
csv_logger_callback_binary_normal_drusen = CSVLogger(
    f"../{octai_model_version}_training_logger_binary_normal_drusen.log",
    separator=",",
    append=False,
)
csv_logger_callback_binary_normal_dme = CSVLogger(
    f"../{octai_model_version}_training_logger_binary_normal_dme.log",
    separator=",",
    append=False,
)

# %%
# we definie our EarlyStopping function to trigger during the training of our binary models
early_stopping_binary = EarlyStopping(
    monitor="val_loss", verbose=1, patience=5, restore_best_weights=True
)

# %%
"""we define a list of metrics we would like to keep track off during the training and be analysed further to asses our
biniary model strenght"""

model_metrics_binary = [
    BinaryAccuracy(),
    TruePositives(),
    TrueNegatives(),
    FalsePositives(),
    FalseNegatives(),
    AUC(),
    Precision(),
    Recall(),
    PrecisionAtRecall(0.5),
    RecallAtPrecision(0.5),
    SensitivityAtSpecificity(0.5),
    SpecificityAtSensitivity(0.5),
    MeanAbsoluteError(),
    R2Score(),
    RootMeanSquaredError(),
]

# %%
# we compile the model and build our binary model
model_octai_binary_normal_cnv.compile(
    loss=BinaryCrossentropy(), optimizer=Adam(), metrics=model_metrics_binary
)
model_octai_binary_normal_drusen.compile(
    loss=BinaryCrossentropy(), optimizer=Adam(), metrics=model_metrics_binary
)
model_octai_binary_normal_dme.compile(
    loss=BinaryCrossentropy(), optimizer=Adam(), metrics=model_metrics_binary
)

model_octai_binary_normal_cnv.build()
model_octai_binary_normal_drusen.build()
model_octai_binary_normal_drusen.build()

model_octai_binary_normal_cnv.summary()
model_octai_binary_normal_drusen.summary()
model_octai_binary_normal_dme.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_4 (Rescaling)              │ (None, 200, 200, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ vgg19 (Functional)                   │ (None, 6, 6, 512)           │      20,024,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 18432)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │          18,433 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,042,817 (76.46 MB)
#  Trainable params: 18,433 (72.00 KB)
#  Non-trainable params: 20,024,384 (76.39 MB)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_5 (Rescaling)              │ (None, 200, 200, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ vgg19 (Functional)                   │ (None, 6, 6, 512)           │      20,024,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_5 (Flatten)                  │ (None, 18432)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │          18,433 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,042,817 (76.46 MB)
#  Trainable params: 18,433 (72.00 KB)
#  Non-trainable params: 20,024,384 (76.39 MB)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_6 (Rescaling)              │ (None, 200, 200, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ vgg19 (Functional)                   │ (None, 6, 6, 512)           │      20,024,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_6 (Flatten)                  │ (None, 18432)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 1)                   │          18,433 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,042,817 (76.46 MB)
#  Trainable params: 18,433 (72.00 KB)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
train_ds_binary_normal_cnv = keras.utils.image_dataset_from_directory(
    directory=train_dir,
    batch_size=TRAIN_BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
    class_names=CLASSES_NORMAL_CNV,
)

train_ds_binary_normal_drusen = keras.utils.image_dataset_from_directory(
    directory=train_dir,
    batch_size=TRAIN_BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
    class_names=CLASSES_NORMAL_DRUSEN,
)

train_ds_binary_normal_dme = keras.utils.image_dataset_from_directory(
    directory=train_dir,
    batch_size=TRAIN_BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
    class_names=CLASSES_NORMAL_DME,
)
# Out:
# Found 62191 files belonging to 2 classes.
# Found 42179 files belonging to 2 classes.
# Found 44091 files belonging to 2 classes.

# %%
val_ds_binary_normal_cnv = keras.utils.image_dataset_from_directory(
    directory=val_dir,
    batch_size=VALIDATION_BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
    class_names=CLASSES_NORMAL_CNV,
)

val_ds_binary_normal_drusen = keras.utils.image_dataset_from_directory(
    directory=val_dir,
    batch_size=VALIDATION_BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
    class_names=CLASSES_NORMAL_DRUSEN,
)

val_ds_binary_normal_dme = keras.utils.image_dataset_from_directory(
    directory=val_dir,
    batch_size=VALIDATION_BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
    class_names=CLASSES_NORMAL_DME,
)
# Out:
# Found 17768 files belonging to 2 classes.
# Found 12050 files belonging to 2 classes.
# Found 12597 files belonging to 2 classes.

# %%
_class_number_binary_normal_cnv = {0: "NORMAL", 1: "CNV"}
_class_weight_model_binary_normal_cnv = {
    k: weigth_binary_normal_cnv[v] for k, v in _class_number_binary_normal_cnv.items()
}

_class_number_binary_normal_drusen = {0: "NORMAL", 1: "DRUSEN"}
_class_weight_model_binary_normal_drusen = {
    k: weigth_binary_normal_drusen[v]
    for k, v in _class_number_binary_normal_drusen.items()
}

_class_number_binary_normal_dme = {0: "NORMAL", 1: "DME"}
_class_weight_model_binary_normal_dme = {
    k: weigth_binary_normal_dme[v] for k, v in _class_number_binary_normal_dme.items()
}

# %%
train_ds_binary_normal_cnv = train_ds_binary_normal_cnv.prefetch(buffer_size=AUTOTUNE)
train_ds_binary_normal_drusen = train_ds_binary_normal_drusen.prefetch(
    buffer_size=AUTOTUNE
)
train_ds_binary_normal_dme = train_ds_binary_normal_dme.prefetch(buffer_size=AUTOTUNE)

val_ds_binary_normal_cnv = val_ds_binary_normal_cnv.prefetch(buffer_size=AUTOTUNE)
val_ds_binary_normal_drusen = val_ds_binary_normal_drusen.prefetch(buffer_size=AUTOTUNE)
val_ds_binary_normal_dme = val_ds_binary_normal_dme.prefetch(buffer_size=AUTOTUNE)

# %%
history_vgg_binary_normal_cnv = model_octai_binary_normal_cnv.fit(
    train_ds_binary_normal_cnv,
    epochs=10,
    validation_data=val_ds_binary_normal_cnv,
    callbacks=[early_stopping_binary, csv_logger_callback],
    class_weight=_class_weight_model_binary_normal_cnv,
    validation_batch_size=VALIDATION_BATCH_SIZE,
)
# Out:
# Epoch 1/10
# 3887/3887 ━━━━━━━━━━━━━━━━━━━━ 479s 121ms/step - auc_3: 0.9940 - binary_accuracy: 0.9697 - false_negatives_3: 475.3493 - false_positives_3: 234.8755 - loss: 0.0397 - mean_absolute_error: 0.0524 - precision_3: 0.9758 - precision_at_recall_3: 0.9977 - r2_score: 0.9057 - recall_3: 0.9507 - recall_at_precision_3: 0.9986 - root_mean_squared_error: 0.1467 - sensitivity_at_specificity_3: 0.9982 - specificity_at_sensitivity_3: 0.9989 - true_negatives_3: 17768.4902 - true_positives_3: 12633.2803 - val_auc_3: 0.9986 - val_binary_accuracy: 0.9915 - val_false_negatives_3: 68.0000 - val_false_positives_3: 83.0000 - val_loss: 0.0287 - val_mean_absolute_error: 0.0132 - val_precision_3: 0.9889 - val_precision_at_recall_3: 0.9991 - val_r2_score: 0.9714 - val_recall_3: 0.9909 - val_recall_at_precision_3: 0.9985 - val_root_mean_squared_error: 0.0835 - val_sensitivity_at_specificity_3: 0.9985 - val_specificity_at_sensitivity_3: 0.9994 - val_true_negatives_3: 10194.0000 - val_true_positives_3: 7423.0000
# Epoch 2/10
# 3887/3887 ━━━━━━━━━━━━━━━━━━━━ 387s 100ms/step - auc_3: 0.9984 - binary_accuracy: 0.9895 - false_negatives_3: 220.2042 - false_positives_3: 123.2160 - loss: 0.0159 - mean_absolute_error: 0.0146 - precision_3: 0.9908 - precision_at_recall_3: 0.9993 - r2_score: 0.9667 - recall_3: 0.9841 - recall_at_precision_3: 0.9982 - root_mean_squared_error: 0.0900 - sensitivity_at_specificity_3: 0.9982 - specificity_at_sensitivity_3: 0.9996 - true_negatives_3: 17879.9316 - true_positives_3: 12888.6426 - val_auc_3: 0.9965 - val_binary_accuracy: 0.9862 - val_false_negatives_3: 236.0000 - val_false_positives_3: 9.0000 - val_loss: 0.0507 - val_mean_absolute_error: 0.0169 - val_precision_3: 0.9988 - val_precision_at_recall_3: 0.9993 - val_r2_score: 0.9537 - val_recall_3: 0.9685 - val_recall_at_precision_3: 0.9937 - val_root_mean_squared_error: 0.1063 - val_sensitivity_at_specificity_3: 0.9937 - val_specificity_at_sensitivity_3: 0.9995 - val_true_negatives_3: 10268.0000 - val_true_positives_3: 7255.0000
# Epoch 3/10
# 3887/3887 ━━━━━━━━━━━━━━━━━━━━ 397s 102ms/step - auc_3: 0.9986 - binary_accuracy: 0.9916 - false_negatives_3: 175.1448 - false_positives_3: 95.9210 - loss: 0.0136 - mean_absolute_error: 0.0118 - precision_3: 0.9928 - precision_at_recall_3: 0.9991 - r2_score: 0.9723 - recall_3: 0.9872 - recall_at_precision_3: 0.9986 - root_mean_squared_error: 0.0820 - sensitivity_at_specificity_3: 0.9986 - specificity_at_sensitivity_3: 0.9994 - true_negatives_3: 17907.3535 - true_positives_3: 12933.5752 - val_auc_3: 0.9986 - val_binary_accuracy: 0.9927 - val_false_negatives_3: 55.0000 - val_false_positives_3: 75.0000 - val_loss: 0.0242 - val_mean_absolute_error: 0.0093 - val_precision_3: 0.9900 - val_precision_at_recall_3: 0.9986 - val_r2_score: 0.9767 - val_recall_3: 0.9927 - val_recall_at_precision_3: 0.9987 - val_root_mean_squared_error: 0.0753 - val_sensitivity_at_specificity_3: 0.9987 - val_specificity_at_sensitivity_3: 0.9990 - val_true_negatives_3: 10202.0000 - val_true_positives_3: 7436.0000
# Epoch 4/10
# 3887/3887 ━━━━━━━━━━━━━━━━━━━━ 433s 100ms/step - auc_3: 0.9990 - binary_accuracy: 0.9931 - false_negatives_3: 141.7531 - false_positives_3: 89.6371 - loss: 0.0108 - mean_absolute_error: 0.0094 - precision_3: 0.9936 - precision_at_recall_3: 0.9991 - r2_score: 0.9776 - recall_3: 0.9899 - recall_at_precision_3: 0.9990 - root_mean_squared_error: 0.0737 - sensitivity_at_specificity_3: 0.9990 - specificity_at_sensitivity_3: 0.9994 - true_negatives_3: 17913.9316 - true_positives_3: 12966.6738 - val_auc_3: 0.9986 - val_binary_accuracy: 0.9935 - val_false_negatives_3: 69.0000 - val_false_positives_3: 47.0000 - val_loss: 0.0232 - val_mean_absolute_error: 0.0079 - val_precision_3: 0.9937 - val_precision_at_recall_3: 0.9989 - val_r2_score: 0.9789 - val_recall_3: 0.9908 - val_recall_at_precision_3: 0.9983 - val_root_mean_squared_error: 0.0717 - val_sensitivity_at_specificity_3: 0.9983 - val_specificity_at_sensitivity_3: 0.9992 - val_true_negatives_3: 10230.0000 - val_true_positives_3: 7422.0000
# Epoch 5/10
# 3887/3887 ━━━━━━━━━━━━━━━━━━━━ 449s 102ms/step - auc_3: 0.9991 - binary_accuracy: 0.9930 - false_negatives_3: 139.2796 - false_positives_3: 79.5548 - loss: 0.0100 - mean_absolute_error: 0.0090 - precision_3: 0.9941 - precision_at_recall_3: 0.9993 - r2_score: 0.9786 - recall_3: 0.9893 - recall_at_precision_3: 0.9990 - root_mean_squared_error: 0.0721 - sensitivity_at_specificity_3: 0.9990 - specificity_at_sensitivity_3: 0.9995 - true_negatives_3: 17923.9863 - true_positives_3: 12969.1738 - val_auc_3: 0.9989 - val_binary_accuracy: 0.9939 - val_false_negatives_3: 58.0000 - val_false_positives_3: 51.0000 - val_loss: 0.0217 - val_mean_absolute_error: 0.0078 - val_precision_3: 0.9932 - val_precision_at_recall_3: 0.9990 - val_r2_score: 0.9795 - val_recall_3: 0.9923 - val_recall_at_precision_3: 0.9988 - val_root_mean_squared_error: 0.0706 - val_sensitivity_at_specificity_3: 0.9988 - val_specificity_at_sensitivity_3: 0.9993 - val_true_negatives_3: 10226.0000 - val_true_positives_3: 7433.0000
# Epoch 6/10
# 3887/3887 ━━━━━━━━━━━━━━━━━━━━ 444s 102ms/step - auc_3: 0.9992 - binary_accuracy: 0.9942 - false_negatives_3: 116.1209 - false_positives_3: 68.9568 - loss: 0.0087 - mean_absolute_error: 0.0078 - precision_3: 0.9949 - precision_at_recall_3: 0.9992 - r2_score: 0.9815 - recall_3: 0.9913 - recall_at_precision_3: 0.9992 - root_mean_squared_error: 0.0671 - sensitivity_at_specificity_3: 0.9992 - specificity_at_sensitivity_3: 0.9994 - true_negatives_3: 17934.8086 - true_positives_3: 12992.1084 - val_auc_3: 0.9986 - val_binary_accuracy: 0.9942 - val_false_negatives_3: 71.0000 - val_false_positives_3: 32.0000 - val_loss: 0.0212 - val_mean_absolute_error: 0.0071 - val_precision_3: 0.9957 - val_precision_at_recall_3: 0.9988 - val_r2_score: 0.9805 - val_recall_3: 0.9905 - val_recall_at_precision_3: 0.9983 - val_root_mean_squared_error: 0.0689 - val_sensitivity_at_specificity_3: 0.9983 - val_specificity_at_sensitivity_3: 0.9991 - val_true_negatives_3: 10245.0000 - val_true_positives_3: 7420.0000
# Epoch 7/10
# 3887/3887 ━━━━━━━━━━━━━━━━━━━━ 388s 100ms/step - auc_3: 0.9993 - binary_accuracy: 0.9950 - false_negatives_3: 106.4807 - false_positives_3: 54.5556 - loss: 0.0077 - mean_absolute_error: 0.0072 - precision_3: 0.9960 - precision_at_recall_3: 0.9996 - r2_score: 0.9835 - recall_3: 0.9921 - recall_at_precision_3: 0.9991 - root_mean_squared_error: 0.0632 - sensitivity_at_specificity_3: 0.9991 - specificity_at_sensitivity_3: 0.9997 - true_negatives_3: 17948.9648 - true_positives_3: 13001.9941 - val_auc_3: 0.9983 - val_binary_accuracy: 0.9938 - val_false_negatives_3: 90.0000 - val_false_positives_3: 21.0000 - val_loss: 0.0249 - val_mean_absolute_error: 0.0076 - val_precision_3: 0.9972 - val_precision_at_recall_3: 0.9992 - val_r2_score: 0.9781 - val_recall_3: 0.9880 - val_recall_at_precision_3: 0.9973 - val_root_mean_squared_error: 0.0731 - val_sensitivity_at_specificity_3: 0.9973 - val_specificity_at_sensitivity_3: 0.9994 - val_true_negatives_3: 10256.0000 - val_true_positives_3: 7401.0000
# Epoch 8/10
# 3887/3887 ━━━━━━━━━━━━━━━━━━━━ 442s 100ms/step - auc_3: 0.9993 - binary_accuracy: 0.9952 - false_negatives_3: 96.6229 - false_positives_3: 58.2325 - loss: 0.0080 - mean_absolute_error: 0.0068 - precision_3: 0.9957 - precision_at_recall_3: 0.9993 - r2_score: 0.9838 - recall_3: 0.9929 - recall_at_precision_3: 0.9993 - root_mean_squared_error: 0.0627 - sensitivity_at_specificity_3: 0.9993 - specificity_at_sensitivity_3: 0.9995 - true_negatives_3: 17945.4277 - true_positives_3: 13011.7119 - val_auc_3: 0.9980 - val_binary_accuracy: 0.9926 - val_false_negatives_3: 113.0000 - val_false_positives_3: 19.0000 - val_loss: 0.0282 - val_mean_absolute_error: 0.0084 - val_precision_3: 0.9974 - val_precision_at_recall_3: 0.9994 - val_r2_score: 0.9751 - val_recall_3: 0.9849 - val_recall_at_precision_3: 0.9965 - val_root_mean_squared_error: 0.0779 - val_sensitivity_at_specificity_3: 0.9965 - val_specificity_at_sensitivity_3: 0.9996 - val_true_negatives_3: 10258.0000 - val_true_positives_3: 7378.0000
# Epoch 9/10
# 3887/3887 ━━━━━━━━━━━━━━━━━━━━ 385s 99ms/step - auc_3: 0.9997 - binary_accuracy: 0.9957 - false_negatives_3: 85.8917 - false_positives_3: 50.1075 - loss: 0.0063 - mean_absolute_error: 0.0057 - precision_3: 0.9961 - precision_at_recall_3: 0.9997 - r2_score: 0.9864 - recall_3: 0.9936 - recall_at_precision_3: 0.9997 - root_mean_squared_error: 0.0576 - sensitivity_at_specificity_3: 0.9997 - specificity_at_sensitivity_3: 0.9998 - true_negatives_3: 17953.2227 - true_positives_3: 13022.7725 - val_auc_3: 0.9991 - val_binary_accuracy: 0.9939 - val_false_negatives_3: 45.0000 - val_false_positives_3: 63.0000 - val_loss: 0.0212 - val_mean_absolute_error: 0.0075 - val_precision_3: 0.9916 - val_precision_at_recall_3: 0.9989 - val_r2_score: 0.9800 - val_recall_3: 0.9940 - val_recall_at_precision_3: 0.9992 - val_root_mean_squared_error: 0.0699 - val_sensitivity_at_specificity_3: 0.9992 - val_specificity_at_sensitivity_3: 0.9992 - val_true_negatives_3: 10214.0000 - val_true_positives_3: 7446.0000
# Epoch 10/10
# 3887/3887 ━━━━━━━━━━━━━━━━━━━━ 389s 100ms/step - auc_3: 0.9993 - binary_accuracy: 0.9947 - false_negatives_3: 96.9666 - false_positives_3: 61.2760 - loss: 0.0080 - mean_absolute_error: 0.0067 - precision_3: 0.9949 - precision_at_recall_3: 0.9995 - r2_score: 0.9829 - recall_3: 0.9925 - recall_at_precision_3: 0.9992 - root_mean_squared_error: 0.0639 - sensitivity_at_specificity_3: 0.9992 - specificity_at_sensitivity_3: 0.9997 - true_negatives_3: 17942.3066 - true_positives_3: 13011.4453 - val_auc_3: 0.9982 - val_binary_accuracy: 0.9934 - val_false_negatives_3: 100.0000 - val_false_positives_3: 17.0000 - val_loss: 0.0271 - val_mean_absolute_error: 0.0078 - val_precision_3: 0.9977 - val_precision_at_recall_3: 0.9996 - val_r2_score: 0.9770 - val_recall_3: 0.9867 - val_recall_at_precision_3: 0.9968 - val_root_mean_squared_error: 0.0749 - val_sensitivity_at_specificity_3: 0.9968 - val_specificity_at_sensitivity_3: 0.9997 - val_true_negatives_3: 10260.0000 - val_true_positives_3: 7391.0000
# Restoring model weights from the end of the best epoch: 9.

# %%
# we save our trained model
model_octai_binary_normal_cnv.save(f"{octai_model_version}_binary_normal_cnv_.keras")

# serialize model to JSON
model_json = model_octai_binary_normal_cnv.to_json()
with open(file=f"{octai_model_version}_binary_normal_cnv.json", mode="w") as json_file:
    json_file.write(model_json)

# serialize weights to HDF5
model_octai_binary_normal_cnv.save_weights(
    f"{octai_model_version}_binary_normal_cnv.weights.h5"
)

# %%
# we define the metrics we chose to display for our binary models
display_metrics = [
    "accuracy",
    "auc",
    "categorical_accuracy",
    "loss",
    "mean_absolute_error",
    "precision",
    "precision_at_recall",
    "r2_score",
    "recall",
    "recall_at_precision",
    "root_mean_squared_error",
    "sensitivity_at_specificity",
    "specificity_at_sensitivity",
]

display_metrics = [
    m for m in history_vgg_binary_normal_cnv.history.keys() if "val_" not in m
]
display_metrics = [m for m in display_metrics if "f1_" not in m]

# %%
plt.rcParams["axes.grid"] = True
for (
    train_metric_name,
    train_metric_value,
) in history_vgg_binary_normal_cnv.history.items():
    if train_metric_name in display_metrics:
        val_metric_name = "val_" + train_metric_name

        train_metric_data = dict(
            zip(
                range(len(history_vgg_binary_normal_cnv.history[train_metric_name])),
                history_vgg_binary_normal_cnv.history[train_metric_name],
            )
        )
        val_metric_data = dict(
            zip(
                range(len(history_vgg_binary_normal_cnv.history[val_metric_name])),
                history_vgg_binary_normal_cnv.history[val_metric_name],
            )
        )
        sns.lineplot(
            data=train_metric_data,
            x=train_metric_data.keys(),
            y=train_metric_data.values(),
            label="Train Data",
        )
        sns.lineplot(
            data=val_metric_data,
            x=val_metric_data.keys(),
            y=val_metric_data.values(),
            label="Validation Data",
        )
        ax = plt.gca()  # we could display zoomed and non zoomed graphs
        ax.set_ylim(bottom=[0, 1])
        plt.xlabel(xlabel="Epochs")
        metric = train_metric_name.replace("_", " ")
        plt.ylabel(ylabel=metric)
        plt.title(label=f"Training and validation {metric}")
        plt.legend()
        plt.show()
        print("")

# %%
test_ds_binary_normal_cnv = keras.utils.image_dataset_from_directory(
    directory=test_dir,
    batch_size=VALIDATION_BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
    class_names=CLASSES_NORMAL_CNV,
    shuffle=False,
)

test_ds_binary_normal_drusen = keras.utils.image_dataset_from_directory(
    directory=test_dir,
    batch_size=VALIDATION_BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
    class_names=CLASSES_NORMAL_DRUSEN,
    shuffle=False,
)

test_ds_binary_normal_dme = keras.utils.image_dataset_from_directory(
    directory=test_dir,
    batch_size=VALIDATION_BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
    class_names=CLASSES_NORMAL_DME,
    shuffle=False,
)
# Out:
# Found 8886 files belonging to 2 classes.
# Found 6027 files belonging to 2 classes.
# Found 6300 files belonging to 2 classes.

# %%
# we evaluate our trained model with our test data
baseline_results_binary_normal_cnv = model_octai_binary_normal_cnv.evaluate(
    test_ds_binary_normal_cnv
)
# Out:
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 68s 122ms/step - auc_3: 0.4234 - binary_accuracy: 0.9950 - false_negatives_3: 4.2047 - false_positives_3: 21.6750 - loss: 0.0175 - mean_absolute_error: 0.0074 - precision_3: 0.4069 - precision_at_recall_3: 0.4216 - r2_score: 0.3989 - recall_3: 0.4215 - recall_at_precision_3: 0.4232 - root_mean_squared_error: 0.0647 - sensitivity_at_specificity_3: 0.4234 - specificity_at_sensitivity_3: 0.4235 - true_negatives_3: 3640.6875 - true_positives_3: 797.3680

# %%
for name, value in zip(
    ["loss"] + [metric.name for metric in model_metrics],
    baseline_results_binary_normal_cnv,
):
    print(name, ": ", value)
# Out:
# loss :  0.01891615241765976
# categorical_accuracy :  0.9943731427192688
# auc :  3728.0
# f1_score :  5108.0
# precision :  32.0
# recall :  18.0
# accuracy :  0.999324381351471
# root_mean_squared_error :  0.9914893507957458
# r2_score :  0.9951948523521423
# mean_absolute_error :  0.9991814494132996
# true_positives :  0.9994661211967468
# true_negatives :  0.9994661211967468
# false_positives :  0.9994163513183594
# false_negatives :  0.007398026064038277
# precision_at_recall :  0.9808713793754578
# recall_at_precision :  0.06829685717821121

# %%
predicted_classes = np.argmax(a=predictions, axis=1)
predicted_classes
